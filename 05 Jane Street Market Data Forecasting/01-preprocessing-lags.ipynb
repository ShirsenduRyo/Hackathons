# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 0. Import Packages

# %%
import pandas as pd
import polars as pl
import numpy as np
import gc
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import StratifiedGroupKFold

# %% [markdown]
# # 1. Configs

# %%
class CONFIG:
    target_col = "responder_6"
    lag_cols_original = ["date_id", "symbol_id"] + [f"responder_{idx}" for idx in range(9)]
    lag_cols_rename = { f"responder_{idx}" : f"responder_{idx}_lag_1" for idx in range(9)}
    valid_ratio = 0.05
    start_dt = 1100

# %% [markdown]
# # 2. Load Traing Data

# %%
train = pl.scan_parquet(
    f"/kaggle/input/jane-street-real-time-market-data-forecasting/train.parquet"
).select(
    pl.int_range(pl.len(), dtype=pl.UInt32).alias("id"),
    pl.all(),
).with_columns(
    (pl.col(CONFIG.target_col)*2).cast(pl.Int32).alias("label"),
).filter(
    pl.col("date_id").gt(CONFIG.start_dt)
)

# %%
lags = train.select(pl.col(CONFIG.lag_cols_original))
lags = lags.rename(CONFIG.lag_cols_rename)
lags = lags.with_columns(
    date_id = pl.col('date_id') + 1,  # lagged by 1 day
    )
lags = lags.group_by(["date_id", "symbol_id"], maintain_order=True).last()  # pick up last record of previous date
lags
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="1679pt" height="567pt"
#  viewBox="0.00 0.00 1679.00 567.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 563)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-563 1675,-563 1675,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="1671,-559 0,-559 0,-506 1671,-506 1671,-559"/>
# <text text-anchor="middle" x="835.5" y="-543.8" font-family="Times,serif" font-size="14.00">AGG [col(&quot;responder_0_lag_1&quot;).last(), col(&quot;responder_1_lag_1&quot;).last(), col(&quot;responder_2_lag_1&quot;).last(), col(&quot;responder_3_lag_1&quot;).last(), col(&quot;responder_4_lag_1&quot;).last(), col(&quot;responder_5_lag_1&quot;).last(), col(&quot;responder_6_lag_1&quot;).last(), col(&quot;responder_7_lag_1&quot;).last(), col(&quot;responder_8_lag_1&quot;).last()]</text>
# <text text-anchor="middle" x="835.5" y="-528.8" font-family="Times,serif" font-size="14.00">BY</text>
# <text text-anchor="middle" x="835.5" y="-513.8" font-family="Times,serif" font-size="14.00">[col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="1011.5,-470 659.5,-470 659.5,-434 1011.5,-434 1011.5,-470"/>
# <text text-anchor="middle" x="835.5" y="-448.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;date_id&quot;)) + (1)].alias(&quot;date_id&quot;)]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M835.5,-505.8C835.5,-494.17 835.5,-480.74 835.5,-470.33"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="872.5,-398 798.5,-398 798.5,-362 872.5,-362 872.5,-398"/>
# <text text-anchor="middle" x="835.5" y="-376.3" font-family="Times,serif" font-size="14.00">RENAME</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M835.5,-433.7C835.5,-422.85 835.5,-408.92 835.5,-398.1"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="864.5,-326 806.5,-326 806.5,-290 864.5,-290 864.5,-326"/>
# <text text-anchor="middle" x="835.5" y="-304.3" font-family="Times,serif" font-size="14.00">π 11/11</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M835.5,-361.7C835.5,-350.85 835.5,-336.92 835.5,-326.1"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="953,-254 718,-254 718,-218 953,-218 953,-254"/>
# <text text-anchor="middle" x="835.5" y="-232.3" font-family="Times,serif" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M835.5,-289.7C835.5,-278.85 835.5,-264.92 835.5,-254.1"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="1070.5,-182 600.5,-182 600.5,-146 1070.5,-146 1070.5,-182"/>
# <text text-anchor="middle" x="835.5" y="-160.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p5&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p5&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M835.5,-217.7C835.5,-206.85 835.5,-192.92 835.5,-182.1"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="864.5,-110 806.5,-110 806.5,-74 864.5,-74 864.5,-110"/>
# <text text-anchor="middle" x="835.5" y="-88.3" font-family="Times,serif" font-size="14.00">π 94/94</text>
# </g>
# <!-- p6&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p6&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M835.5,-145.7C835.5,-134.85 835.5,-120.92 835.5,-110.1"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1211.5,-38 459.5,-38 459.5,0 1211.5,0 1211.5,-38"/>
# <text text-anchor="middle" x="835.5" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [/kaggle/input/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other files]</text>
# <text text-anchor="middle" x="835.5" y="-7.8" font-family="Times,serif" font-size="14.00">π */93;</text>
# </g>
# <!-- p7&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p7&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M835.5,-73.81C835.5,-62.98 835.5,-49.01 835.5,-38.02"/>
# </g>
# </g>
# </svg>

# %%
train = train.join(lags, on=["date_id", "symbol_id"],  how="left")
train
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="2191pt" height="658pt"
#  viewBox="0.00 0.00 2190.50 658.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 654)">
# <title>polars_query</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-654 2186.5,-654 2186.5,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="980.5,-650 741.5,-650 741.5,-597 980.5,-597 980.5,-650"/>
# <text text-anchor="middle" x="861" y="-634.8" font-family="Times,serif" font-size="14.00">JOIN LEFT</text>
# <text text-anchor="middle" x="861" y="-619.8" font-family="Times,serif" font-size="14.00">left: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)];</text>
# <text text-anchor="middle" x="861" y="-604.8" font-family="Times,serif" font-size="14.00">right: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p2 -->
# <g id="node2" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="493.5,-552.5 258.5,-552.5 258.5,-516.5 493.5,-516.5 493.5,-552.5"/>
# <text text-anchor="middle" x="376" y="-530.8" font-family="Times,serif" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p1&#45;&#45;p2 -->
# <g id="edge1" class="edge">
# <title>p1&#45;&#45;p2</title>
# <path fill="none" stroke="black" d="M741.17,-602.9C671.31,-591.24 581.56,-575.86 502,-561 487.85,-558.36 472.83,-555.43 458.28,-552.52"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="2182.5,-561 511.5,-561 511.5,-508 2182.5,-508 2182.5,-561"/>
# <text text-anchor="middle" x="1347" y="-545.8" font-family="Times,serif" font-size="14.00">AGG [col(&quot;responder_0_lag_1&quot;).last(), col(&quot;responder_1_lag_1&quot;).last(), col(&quot;responder_2_lag_1&quot;).last(), col(&quot;responder_3_lag_1&quot;).last(), col(&quot;responder_4_lag_1&quot;).last(), col(&quot;responder_5_lag_1&quot;).last(), col(&quot;responder_6_lag_1&quot;).last(), col(&quot;responder_7_lag_1&quot;).last(), col(&quot;responder_8_lag_1&quot;).last()]</text>
# <text text-anchor="middle" x="1347" y="-530.8" font-family="Times,serif" font-size="14.00">BY</text>
# <text text-anchor="middle" x="1347" y="-515.8" font-family="Times,serif" font-size="14.00">[col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p1&#45;&#45;p6 -->
# <g id="edge5" class="edge">
# <title>p1&#45;&#45;p6</title>
# <path fill="none" stroke="black" d="M980.51,-601.11C1048.11,-589.01 1133.06,-573.8 1204.15,-561.07"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="611,-472 141,-472 141,-436 611,-436 611,-472"/>
# <text text-anchor="middle" x="376" y="-450.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p2&#45;&#45;p3 -->
# <g id="edge2" class="edge">
# <title>p2&#45;&#45;p3</title>
# <path fill="none" stroke="black" d="M376,-516.47C376,-503.3 376,-485.16 376,-472"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="405,-400 347,-400 347,-364 405,-364 405,-400"/>
# <text text-anchor="middle" x="376" y="-378.3" font-family="Times,serif" font-size="14.00">π 94/94</text>
# </g>
# <!-- p3&#45;&#45;p4 -->
# <g id="edge3" class="edge">
# <title>p3&#45;&#45;p4</title>
# <path fill="none" stroke="black" d="M376,-435.7C376,-424.85 376,-410.92 376,-400.1"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="752,-328 0,-328 0,-290 752,-290 752,-328"/>
# <text text-anchor="middle" x="376" y="-312.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [/kaggle/input/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other files]</text>
# <text text-anchor="middle" x="376" y="-297.8" font-family="Times,serif" font-size="14.00">π */93;</text>
# </g>
# <!-- p4&#45;&#45;p5 -->
# <g id="edge4" class="edge">
# <title>p4&#45;&#45;p5</title>
# <path fill="none" stroke="black" d="M376,-363.81C376,-352.98 376,-339.01 376,-328.02"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="1523,-472 1171,-472 1171,-436 1523,-436 1523,-472"/>
# <text text-anchor="middle" x="1347" y="-450.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;date_id&quot;)) + (1)].alias(&quot;date_id&quot;)]</text>
# </g>
# <!-- p6&#45;&#45;p7 -->
# <g id="edge6" class="edge">
# <title>p6&#45;&#45;p7</title>
# <path fill="none" stroke="black" d="M1347,-507.8C1347,-496.17 1347,-482.74 1347,-472.33"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1384,-400 1310,-400 1310,-364 1384,-364 1384,-400"/>
# <text text-anchor="middle" x="1347" y="-378.3" font-family="Times,serif" font-size="14.00">RENAME</text>
# </g>
# <!-- p7&#45;&#45;p8 -->
# <g id="edge7" class="edge">
# <title>p7&#45;&#45;p8</title>
# <path fill="none" stroke="black" d="M1347,-435.7C1347,-424.85 1347,-410.92 1347,-400.1"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="1376,-327 1318,-327 1318,-291 1376,-291 1376,-327"/>
# <text text-anchor="middle" x="1347" y="-305.3" font-family="Times,serif" font-size="14.00">π 11/11</text>
# </g>
# <!-- p8&#45;&#45;p9 -->
# <g id="edge8" class="edge">
# <title>p8&#45;&#45;p9</title>
# <path fill="none" stroke="black" d="M1347,-363.81C1347,-352.65 1347,-338.16 1347,-327.03"/>
# </g>
# <!-- p10 -->
# <g id="node10" class="node">
# <title>p10</title>
# <polygon fill="none" stroke="black" points="1464.5,-254 1229.5,-254 1229.5,-218 1464.5,-218 1464.5,-254"/>
# <text text-anchor="middle" x="1347" y="-232.3" font-family="Times,serif" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p9&#45;&#45;p10 -->
# <g id="edge9" class="edge">
# <title>p9&#45;&#45;p10</title>
# <path fill="none" stroke="black" d="M1347,-290.81C1347,-279.65 1347,-265.16 1347,-254.03"/>
# </g>
# <!-- p11 -->
# <g id="node11" class="node">
# <title>p11</title>
# <polygon fill="none" stroke="black" points="1582,-182 1112,-182 1112,-146 1582,-146 1582,-182"/>
# <text text-anchor="middle" x="1347" y="-160.3" font-family="Times,serif" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p10&#45;&#45;p11 -->
# <g id="edge10" class="edge">
# <title>p10&#45;&#45;p11</title>
# <path fill="none" stroke="black" d="M1347,-217.7C1347,-206.85 1347,-192.92 1347,-182.1"/>
# </g>
# <!-- p12 -->
# <g id="node12" class="node">
# <title>p12</title>
# <polygon fill="none" stroke="black" points="1376,-110 1318,-110 1318,-74 1376,-74 1376,-110"/>
# <text text-anchor="middle" x="1347" y="-88.3" font-family="Times,serif" font-size="14.00">π 94/94</text>
# </g>
# <!-- p11&#45;&#45;p12 -->
# <g id="edge11" class="edge">
# <title>p11&#45;&#45;p12</title>
# <path fill="none" stroke="black" d="M1347,-145.7C1347,-134.85 1347,-120.92 1347,-110.1"/>
# </g>
# <!-- p13 -->
# <g id="node13" class="node">
# <title>p13</title>
# <polygon fill="none" stroke="black" points="1723,-38 971,-38 971,0 1723,0 1723,-38"/>
# <text text-anchor="middle" x="1347" y="-22.8" font-family="Times,serif" font-size="14.00">Parquet SCAN [/kaggle/input/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other files]</text>
# <text text-anchor="middle" x="1347" y="-7.8" font-family="Times,serif" font-size="14.00">π */93;</text>
# </g>
# <!-- p12&

# %%
len_train   = train.select(pl.col("date_id")).collect().shape[0]
valid_records = int(len_train * CONFIG.valid_ratio)
len_ofl_mdl = len_train - valid_records
last_tr_dt  = train.select(pl.col("date_id")).collect().row(len_ofl_mdl)[0]

print(f"\n len_train = {len_train}")
print(f"\n len_ofl_mdl = {len_ofl_mdl}")
print(f"\n---> Last offline train date = {last_tr_dt}\n")

training_data = train.filter(pl.col("date_id").le(last_tr_dt))
validation_data   = train.filter(pl.col("date_id").gt(last_tr_dt))
# Out:
#  len_train = 22104280
#
#  len_ofl_mdl = 20999066
#
# ---> Last offline train date = 1669

# %% [markdown]
# # 4. Save The Data

# %%
training_data.collect().\
write_parquet(
    f"training.parquet", partition_by = "date_id",
)
# Out:
# ---------------------------------------------------------------------------
# SchemaFieldNotFoundError                  Traceback (most recent call last)
# <ipython-input-8-509335ed3936> in <cell line: 1>()
# ----> 1 training_data.collect().\
#       2 write_parquet(
#       3     f"training.parquet", partition_by = "date_id",
#       4 )
#
# /usr/local/lib/python3.10/dist-packages/polars/lazyframe/frame.py in collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2032         # Only for testing purposes
#    2033         callback = _kwargs.get("post_opt_callback", callback)
# -> 2034         return wrap_df(ldf.collect(callback))
#    2035
#    2036     @overload
#
# SchemaFieldNotFoundError: projection index 92 is out of bounds for schema of length 92

# %%
validation_data.collect().\
write_parquet(
    "validation.parquet", partition_by = "date_id",
)
# Out:
# ---------------------------------------------------------------------------
# SchemaFieldNotFoundError                  Traceback (most recent call last)
# <ipython-input-9-756e6ee1d5a3> in <cell line: 1>()
# ----> 1 validation_data.collect().\
#       2 write_parquet(
#       3     "validation.parquet", partition_by = "date_id",
#       4 )
#
# /usr/local/lib/python3.10/dist-packages/polars/lazyframe/frame.py in collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2032         # Only for testing purposes
#    2033         callback = _kwargs.get("post_opt_callback", callback)
# -> 2034         return wrap_df(ldf.collect(callback))
#    2035
#    2036     @overload
#
# SchemaFieldNotFoundError: projection index 92 is out of bounds for schema of length 92

# %%
print(validation_data.schema)
# Out:
# ---------------------------------------------------------------------------
# SchemaFieldNotFoundError                  Traceback (most recent call last)
# <ipython-input-11-e5b5840c9421> in <cell line: 1>()
# ----> 1 validation_data.collect()
#
# /usr/local/lib/python3.10/dist-packages/polars/lazyframe/frame.py in collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2032         # Only for testing purposes
#    2033         callback = _kwargs.get("post_opt_callback", callback)
# -> 2034         return wrap_df(ldf.collect(callback))
#    2035
#    2036     @overload
#
# SchemaFieldNotFoundError: projection index 92 is out of bounds for schema of length 92
